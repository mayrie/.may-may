# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data=pd.read_csv("C:\\Users\\SOMHI\\Desktop\\msc project\\spss project_1 - Copy - Copy - Copy1.csv")

# %%
data =raw_data.copy()
data
# Out:
#     promotion age religion maritalstatus academicqualification  \
# 0           1   2        1             1                     2
# 1           0   2        1             1                     2
# 2           1   2        1             1                     2
# 3           0   1        1             1                     1
# 4           1   3        1             2                     3
# 5           0   1        1             1                     2
# 6           0   1        1             2                     2
# 7           0   1        2             1                     1
# 8           0   2        1             2                     2
# 9           0   1        1             1                     3
# 10          0   2        1             1                     2
# 11          0   2        1             1                     3
# 12          0   2        1             2                     2
# 13          1   2        2             2                     3
# ...

# %%
data.columns=["promotion","age","religion","maritalstatus","academicqualifications", "noofchildreneverhad","workingexperience", "currentworkposition"]
print(data.columns)
# Out:
# Index(['promotion', 'age', 'religion', 'maritalstatus',
#        'academicqualifications', 'noofchildreneverhad', 'workingexperience',
#        'currentworkposition'],
#       dtype='object')

# %%
print(data.describe())
# Out:
#        promotion  age religion maritalstatus academicqualifications  \
# count        219  219      219           219                    219
# unique         3    5        3             4                      6
# top            0    2        1             1                      2
# freq         121  118      179           126                    123
#
#        noofchildreneverhad workingexperience currentworkposition
# count                  219               219                 219
# unique                   7                 6                  27
# top                      6                 1                   7
# freq                   113               118                  46

# %%
print(pd.crosstab(data["promotion"],data["workingexperience"], rownames= ["promotion"]))
# Out:
# workingexperience      1   2   3  4  5
# promotion
#                    1   4   0   0  0  0
# 0                  5  84  23   8  1  0
# 1                  3  30  30  25  4  1

# %%
df.hist()
pl.show()

# %%
dummy_ranks=pd.get_dummies(df['maritalstatus'], prefix="maritalstatus")
print(dummy_ranks.head())
# Out:
#    maritalstatus_   maritalstatus_1  maritalstatus_2  maritalstatus_4
# 0                0                1                0                0
# 1                0                1                0                0
# 2                0                1                0                0
# 3                0                1                0                0
# 4                0                0                1                0

# %%
cols_to_keep = ["promotion","age", "religion", "academicqualification", "noofchildreneverhad", "currentworkposition"]
data=df[cols_to_keep].join(dummy_ranks.iloc[:,0:3])
data
# Out:
#     promotion age religion academicqualification noofchildreneverhad  \
# 0           1   2        1                     2                   6
# 1           0   2        1                     2                   6
# 2           1   2        1                     2                   6
# 3           0   1        1                     1                   6
# 4           1   3        1                     3                   2
# 5           0   1        1                     2                   6
# 6           0   1        1                     2                   1
# 7           0   1        2                     1                   6
# 8           0   2        1                     2                   1
# 9           0   1        1                     3                   6
# 10          0   2        1                     2                   6
# 11          0   2        1                     3                   6
# 12          0   2        1                     2                   6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 9 columns):
# promotion                219 non-null object
# age                      219 non-null object
# religion                 219 non-null object
# academicqualification    219 non-null object
# noofchildreneverhad      219 non-null object
# currentworkposition      219 non-null object
# maritalstatus_           219 non-null uint8
# maritalstatus_1          219 non-null uint8
# maritalstatus_2          219 non-null uint8
# dtypes: object(6), uint8(3)
# memory usage: 11.0+ KB

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(colour_code=True)

# %%
raw_data=pd.read_csv("C:\\Users\\SOMHI\\Desktop\\msc project\\spss project_1 - career.csv")
data=raw_data.copy()
data
# Out:
#     humanfactors familyfactors improveprofessionalcapabilities  \
# 0              3             3                            5.00
# 1              3             3                            4.00
# 2              3             3                            2.00
# 3              3             5                            4.00
# 4              2             2                            3.00
# 5              4             4                            4.00
# 6              5             3                            5.00
# 7              3             3                            4.00
# 8              5             4                            5.00
# 9              3             5                            1.00
# 10             4             4                            3.00
# 11             1             2                            1.00
# 12             4             4                            4.00
# 13             4             4                            4.00
# ...

# %%
data.isnull().sum()
# Out:
# humanfactors                                 0
# familyfactors                                0
# improveprofessionalcapabilities              0
# jobrelatedknowledge                          0
# jobsarerelevant                              0
# jobsetfoundationfortherealizationofmygaol    0
# careeradvancement                            0
# dtype: int64

# %%
data_no_mv =data.dropna(axis=0)

# %%
data_no_mv.describe(include="all")
# Out:
#        humanfactors familyfactors improveprofessionalcapabilities  \
# count           219           219                             219
# unique            6             6                               6
# top               4             4                            4.00
# freq            113            86                             104
#
#        jobrelatedknowledge jobsarerelevant  \
# count                  219             219
# unique                   6               6
# top                   4.00            4.00
# freq                    98             108
#
#        jobsetfoundationfortherealizationofmygaol careeradvancement
# count                                        219               219
# unique                                         6                 5
# top                                         4.00                 3
# freq                                          87               106

# %%
data_no_mv=np.random.normal(size=219)
sns.distplot(data_no_mv);

# %%
N= 219
x=np.random.rand(N)
y=np.random.rand(N)
colours =(0,0,0)
area=np.pi*3

# %%
plt.scatter(x,y, s=area, c=colours, alpha= 0.5)
plt.title("scatter plot pythonspot.com")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
